# %%
# !nvidia-smi
# Out:
# Sat Dec  9 14:14:53 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Downloading Images

# %%
# install bing images downloader package
# !pip install bing-image-downloader
# Out:
# Collecting bing-image-downloader
#   Downloading bing_image_downloader-1.1.2-py3-none-any.whl (5.9 kB)
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.1.2

# %%
# !mkdir data

# %%
from bing_image_downloader import downloader
common_cat_breeds = ['Maine Coon', 'Persian Cat', 'American Shorthair', 'Siamese Cat'] #
for cat in common_cat_breeds:
  downloader.download(cat, limit=350,  output_dir='data', timeout=60)
# Out:
# [%] Downloading Images to /content/data/Maine Coon
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://mainecoonhawaii.com/wp-content/uploads/2020/06/Ludo-rsz-1.jpg
# [!] Issue getting: https://mainecoonhawaii.com/wp-content/uploads/2020/06/Ludo-rsz-1.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #1 from https://imagesvc.meredithcorp.io/v3/mm/image?url=https:%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F47%2F2020%2F08%2F16%2Fmaine-coon-992070132-2000.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://4.bp.blogspot.com/-kLjgbxbdd3M/Wk_uRD6-UUI/AAAAAAAAHc0/1KHrzTYs-QsbDjEZRw1AU6XturrQKuMRwCLcBGAs/s1600/maine-coon-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.shared.com/content/images/2017/10/maine-coon-cat-photography-robert-sijka-55-57ad8f1b7ddd2__880.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://lifeasahuman.com/files/2020/03/Main-Coon-2-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://4.bp.blogspot.com/-on2JQJZjvUg/UgVG3wEmchI/AAAAAAAAARE/cQpXgGHubxI/s1600/maine-coon-cat3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://3.bp.blogspot.com/-08xprEsotoo/V-vlSd7M1UI/AAAAAAAAAyI/kGhFKKi-ww4ocdurGjp-ZRUgsDhjH3M_QCLcB/s1600/65%2BBreathtaking%2BPictures%2BOf%2BMaine%2BCoons%252C%2BThe%2BLargest%2BCats%2BIn%2BThe%2BWorld.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://static.boredpanda.com/blog/wp-content/uploads/2016/08/maine-coon-cat-photography-robert-sijka-43-57ad8f05d53e9__880.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://3.bp.blogspot.com/-8gnCYUNbyZ8/UgVGyoIybFI/AAAAAAAAAQc/XN1WcvlAaPI/s1600/maine-coon-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://2.bp.blogspot.com/-bu5YKonZIRI/UG16rN-sP-I/AAAAAAAARvI/4VK-YFYyT7o/s1600/Maine+Coon2.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #10 from http://1.bp.blogspot.com/-6f8S4VlIu9U/VN4IGofPgrI/AAAAAAAAAa8/aX-WWjyG3DA/s1600/charming-maine-coon-face-photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from http://purrfectcatbreeds.com/wp-content/uploads/2014/06/maine-coon-cat7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://imagesvc.meredithcorp.io/v3/mm/image?url=https:%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F47%2F2020%2F08%2F16%2Fmaine-coon-full-body-1031504808-2000.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://www.zooplus.de/magazin/wp-content/uploads/2017/03/fotolia_138361424.jpg
# [!] Issue getting: https://www.zooplus.de/magazin/wp-content/uploads/2017/03/fotolia_138361424.jpg
# [!] Error:: HTTP Error 502: Bad Gateway
# [%] Downloading Image #13 from https://consciousreminder.com/wp-content/uploads/2018/10/65-Breathtaking-Pictures-Of-Maine-Coons-The-Largest-Cats-In-The-World-2-696x870.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://i2.wp.com/sassykoonz.com/wp-content/uploads/2018/07/IMG_3834-scaled.jpg?fit=4032%2C3024&amp;ssl=1
# [!] Issue getting: https://i2.wp.com/sassykoonz.com/wp-content/uploads/2018/07/IMG_3834-scaled.jpg?fit=4032%2C3024&amp;ssl=1
# [!] Error:: HTTP Error 404: File Not Found
# [%] Downloading Image #14 from https://www.thehappycatsite.com/wp-content/uploads/2017/12/grey.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://i0.wp.com/www.lifewithcatman.com/wp-content/uploads/2018/06/mainecooncorner_33858129_273360616582419_5810601339964620800_n.jpg?fit=1080,1080
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://www.thehappycatsite.com/wp-content/uploads/2017/12/orange2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from http://www.shared.com/content/images/2017/10/maine-coon-cat-photography-robert-sijka-31-57ad8ef265a45__880.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://www.thehappycatsite.com/wp-content/uploads/2017/12/maine-coon.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://mainecoonhawaii.com/wp-content/uploads/2020/06/Samson-resize-768x576.jpg
# [!] Issue getting: https://mainecoonhawaii.com/wp-content/uploads/2020/06/Samson-resize-768x576.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #19 from https://geniusvets.s3.amazonaws.com/gv-cat-breeds/Maine-Coon-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://www.catsbest.de/wp-content/uploads/Maine-Coon-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://3.bp.blogspot.com/-QZDYh2VHwZY/UG15mfccbzI/AAAAAAAARvA/kVOqxzMMljk/s1600/Maine+Coon.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from http://mainecoon.org/wp-content/uploads/2017/06/maine-coon-cat-2228866_1920.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://usercontent1.hubstatic.com/14134300_f1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://happypurr.com/wp-content/uploads/2020/07/Maine-Coon-Cats.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from http://www.lifewithcatman.com/wp-content/uploads/2018/04/mainecoongram_43037091_291840418323167_1181649036224065720_n.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://www.top13.net/wp-content/uploads/2015/12/huge-maine-coon-cats-12.jpg
# [Error]Invalid image, not saving http://www.top13.net/wp-content/uploads/2015/12/huge-maine-coon-cats-12.jpg
#
# [!] Issue getting: http://www.top13.net/wp-content/uploads/2015/12/huge-maine-coon-cats-12.jpg
# [!] Error:: Invalid image, not saving http://www.top13.net/wp-content/uploads/2015/12/huge-maine-coon-cats-12.jpg
#
# [%] Downloading Image #26 from https://i1.wp.com/www.lifewithcatman.com/wp-content/uploads/2018/06/mainecooncorner_32255776_456877724767263_1882772224998375424_n.jpg?resize=960%2C960
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://www.maine.gov/sos/kids/themes/kids/images/cooncat.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://3.bp.blogspot.com/-N_GhFz4jzJE/V-vikl7BR7I/AAAAAAAAAw8/hoFuDvugzakAJBBWQtomJ-pooDinpu56QCLcB/s1600/65%2BBreathtaking%2BPictures%2BOf%2BMaine%2BCoons%252C%2BThe%2BLargest%2BCats%2BIn%2BThe%2BWorld.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://i.pinimg.com/originals/e8/8c/41/e88c412684232caf3a435f75770479c7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from http://www.beautyofplanet.com/wp-content/uploads/2019/01/1-43.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 30 images.
# [%] Downloading Images to /content/data/Persian Cat
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://1.bp.blogspot.com/-lJGs-FMO5nc/T-XBpob7NrI/AAAAAAAACrQ/SgeZon9cJ4U/s1600/Persian+Cat+images.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://usercontent2.hubstatic.com/12171761_f520.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img.thrfun.com/img/200/610/breed_information_persian_x1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://2.bp.blogspot.com/-POVHZ5n-OhA/VVxkxIBYmHI/AAAAAAAAHeo/iBuuM_YrSdM/s1600/c2ad8f81c412eef4607915f47d300510.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.zastavki.com/pictures/originals/2013/Animals___Cats_Persian_cat_043859_.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://3.bp.blogspot.com/-XGuY67Abfak/T-XBkZBfvdI/AAAAAAAACrI/B3gqLaquQbY/s1600/Persian%2BCat%2Bimage.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://www.pentaxforums.com/gallery/images/3123/1_IMGP7088_Thinned_2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://meowlifestyle.com/wp-content/uploads/2015/05/DSC_0159.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://www.petfriendlyhouse.com/wp-content/uploads/2020/06/persian-cat-facts.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://geniusvets.s3.amazonaws.com/gv-cat-breeds/Persian-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from http://www.catloversdiary.com/wp-content/uploads/2012/11/Persian_Cat.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://images.wallpapersden.com/image/download/persian-cat-cat-furry_amlta5SZmpqtpaSklGdlaW2tZmdtZQ.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://img.thrfun.com/img/076/651/persian_cat_x13.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from http://3.bp.blogspot.com/-4CitidCZZpI/Uk05AIAFgbI/AAAAAAAACNU/b59Vr-CWpP0/s1600/Persian+Cats.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://2.bp.blogspot.com/-FYdn2JfZqRI/T-XGA-PhezI/AAAAAAAACsE/4-a-cBog2iI/s1600/Persian%2BCat%2Bpicture.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from http://2.bp.blogspot.com/-KDqkcqNvuN4/UqYQlj_QUpI/AAAAAAAAXIo/Z8WJqDHpYDs/s1600/persian-cat.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://pulpbits.net/wp-content/uploads/2014/02/grey-persian-cat.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://upload.wikimedia.org/wikipedia/commons/1/15/White_Persian_Cat.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://www.thesprucepets.com/thmb/dm6InsWYL4obgvs3xwcLVGQB6E8=/2309x1299/filters:fill(auto,1)/GreyPersianCatonGreenRug-67bef10b503d4e27b8264bc09f32983c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://cdn.fotofits.com/petzlover/gallery/img/l/persian-552570.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from http://2.bp.blogspot.com/-E8ov2Ddgbvk/TYrBW_TSLBI/AAAAAAAAGng/VbEckCoGOxY/s1600/exotic%2Bshorthair.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from http://2.bp.blogspot.com/-4GWHK5HDLgo/UOKt0m1mMrI/AAAAAAAAAHY/iJDySxZpAfU/s1600/persian-cats.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://www.thehappycatsite.com/wp-content/uploads/2016/10/persian-5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://2.bp.blogspot.com/-ujGhZ9tqSRw/T-XGDd50ptI/AAAAAAAACsM/w34-vGHI3o0/s1600/Persian%2BCat.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from http://2.bp.blogspot.com/-N_viJJOF-_g/T-XBvjzGasI/AAAAAAAACro/yApG6jN-i4U/s1600/Persian+Cat.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://elelur.com/data_images/cat-breeds/persian-cat/persian-cat-01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from http://1.bp.blogspot.com/-jBf2pWr17-k/T-XBuJECSpI/AAAAAAAACrg/55sNaae578s/s1600/Persian%2BCat%2Bpictures.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://www.rvc.ac.uk/Media/Default/VetCompass/images/persian-cat-full.jpg
# [Error]Invalid image, not saving https://www.rvc.ac.uk/Media/Default/VetCompass/images/persian-cat-full.jpg
#
# [!] Issue getting: https://www.rvc.ac.uk/Media/Default/VetCompass/images/persian-cat-full.jpg
# [!] Error:: Invalid image, not saving https://www.rvc.ac.uk/Media/Default/VetCompass/images/persian-cat-full.jpg
#
# [%] Downloading Image #28 from http://2.bp.blogspot.com/-7LXzDaZH60w/TiCo9m21y0I/AAAAAAAAHr4/cdKUYyE4m6M/s1600/persian-cat.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from http://3.bp.blogspot.com/-0FQbpvOXChk/UEtylFIP93I/AAAAAAAABqQ/Owl0pzxnTBM/s1600/458060+Persian,+odd-eyed+white.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://upload.wikimedia.org/wikipedia/commons/3/38/Shaded_silver_Persian_Cat_Missionhill_Cosmic_Rainstorm.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://www.thehappycatsite.com/wp-content/uploads/2016/10/persian-7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://coleandmarmalade.com/wp-content/uploads/2019/07/persian-media.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://www.thesprucepets.com/thmb/QA_JufTkeJEtNXAC4I-xxLd-gpE=/1080x1079/filters:no_upscale():max_bytes(150000):strip_icc()/49361067_1939520546096349_4594151504044784547_n-5c4a0b76c9e77c00011213cd.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from http://1.bp.blogspot.com/-kcB8ocZULTg/UaTFwmDhIvI/AAAAAAAAAOE/dAiIp4BgQ7U/s1600/persian+cat.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #35 from http://pulpbits.net/wp-content/uploads/2014/02/persian-cat-for-sale1.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #36 from http://elelur.com/data_images/cat-breeds/persian-cat/persian-cat-05.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #37 from http://2.bp.blogspot.com/-MJmLLBGH7ZE/T-XF6DaZrYI/AAAAAAAACr8/RtTuGVsjCT4/s1600/Persian%2BCat%2Bimage.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
# [%] Downloading Image #38 from https://persiancatcorner.com/wp-content/uploads/2017/11/IMG_5840.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 7
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 38 images.
# [%] Downloading Images to /content/data/American Shorthair
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/0/0c/American_Shorthair.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.thesprucepets.com/thmb/VXhQbCiva6_2Re-cSqQdecKbhHE=/4778x3185/filters:fill(auto,1)/GettyImages-925319984-36b97d913d934d229d8b0d528a7da64e.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://geniusvets.s3.amazonaws.com/gv-cat-breeds/American-Shorthair-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.thehappycatsite.com/wp-content/uploads/2018/03/american-shorthair-header.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://1.bp.blogspot.com/-YeQgHtssdTo/UJ3BwyXEg3I/AAAAAAAABA0/t0yRXJp3xi0/s1600/American-Shorthair-Cat_Picture.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://1.bp.blogspot.com/-3vtmIxdBkJM/TWmcfRq01FI/AAAAAAAAFfg/51lOx0R68yY/s1600/american-shorthair-5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://elelur.com/data_images/cat-breeds/american-shorthair/american-shorthair-07.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://pawesomecats.com/wp-content/uploads/2016/04/American-Shorthair-cat.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://fishsubsidy.org/wp-content/uploads/2020/01/american-shorthair-cat.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://www.catsbest.eu/wp-content/uploads/American-Shorthair-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from http://www.onlytoptens.com/wp-content/uploads/2012/11/top_10_cat_breeds_american_shorthair.jpg
# [!] Issue getting: http://www.onlytoptens.com/wp-content/uploads/2012/11/top_10_cat_breeds_american_shorthair.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #11 from https://i2.wp.com/www.mascotarios.org/wp-content/uploads/2011/06/american_shorthair.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://1.bp.blogspot.com/-zSn9UrJzv5Y/XVO9p6Su-RI/AAAAAAAABPc/S-sWP16eO2o2mu2yVR0TwUtizpHw9bB5ACLcBGAs/s1600/American_Shorthair.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://3.bp.blogspot.com/-m2PWuWLRsZA/UU7y1pHV43I/AAAAAAAABXY/mG6EH_LO2xA/s1600/American_Shorthair_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from http://proxvost.info/ln/en/short-haired/photo/american_shorthair/american_shorthair_01_large.jpg
# [!] Issue getting: http://proxvost.info/ln/en/short-haired/photo/american_shorthair/american_shorthair_01_large.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #14 from https://www.petful.com/wp-content/uploads/2016/06/american-shorthair-cat.jpg
# [!] Issue getting: https://www.petful.com/wp-content/uploads/2016/06/american-shorthair-cat.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #14 from http://2.bp.blogspot.com/-uEbTFUnZix4/UU7y8lpsbYI/AAAAAAAABXw/u3CUlHkR4Eg/s1600/American_Shorthair_Picture.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.catsincare.com/wp-content/uploads/2017/05/JN_Shorthair8.jpg
# [!] Issue getting: https://www.catsincare.com/wp-content/uploads/2017/05/JN_Shorthair8.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #15 from https://www.cat-world.com.au/wp-content/uploads/2017/02/american-shorthair.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from http://elelur.com/data_images/cat-breeds/american-shorthair/american-shorthair-03.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://img.thrfun.com/img/083/094/american_shorthair_x1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from http://www.cat-breeds-encyclopedia.com/images/American-shorthair-pair.jpg
# [Error]Invalid image, not saving http://www.cat-breeds-encyclopedia.com/images/American-shorthair-pair.jpg
#
# [!] Issue getting: http://www.cat-breeds-encyclopedia.com/images/American-shorthair-pair.jpg
# [!] Error:: Invalid image, not saving http://www.cat-breeds-encyclopedia.com/images/American-shorthair-pair.jpg
#
# [%] Downloading Image #18 from http://www.cat-breeds-encyclopedia.com/images/American-shorthair-cat-tabby.jpg
# [Error]Invalid image, not saving http://www.cat-breeds-encyclopedia.com/images/American-shorthair-cat-tabby.jpg
#
# [!] Issue getting: http://www.cat-breeds-encyclopedia.com/images/American-shorthair-cat-tabby.jpg
# [!] Error:: Invalid image, not saving http://www.cat-breeds-encyclopedia.com/images/American-shorthair-cat-tabby.jpg
#
# [%] Downloading Image #18 from https://icatcare.org/app/uploads/2018/09/American-shorthair.png
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://images.ctfassets.net/440y9b545yd9/250mPrOBEUesyo1imn2SmZ/9c6104c32076f06803834df2aafffe77/American-Shorthair850.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from http://1.bp.blogspot.com/_jZHHRfnq9F8/TVENialAW5I/AAAAAAAAMP0/9dAN2xCjnnw/s1600/American+Shorthairs.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://alchetron.com/cdn/american-shorthair-f75351a7-c38b-4315-afa2-565e6715d89-resize-750.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://www.hepper.com/wp-content/uploads/2021/08/calico-american-shorthair_Tramp57_Shutterstock.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from http://www.hdwallpapers.in/walls/american_shorthair_kitten-wide.jpg
# [Error]Invalid image, not saving http://www.hdwallpapers.in/walls/american_shorthair_kitten-wide.jpg
#
# [!] Issue getting: http://www.hdwallpapers.in/walls/american_shorthair_kitten-wide.jpg
# [!] Error:: Invalid image, not saving http://www.hdwallpapers.in/walls/american_shorthair_kitten-wide.jpg
#
# [%] Downloading Image #23 from https://img.chatsdumonde.com/img/races-de-chats/2161_big-american-shorthair.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://cdn.fotofits.com/petzlover/gallery/img/l/american-shorthair-kitten-856158.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://cdn.fotofits.com/petzlover/gallery/img/l/american-shorthair-kittens-856160.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://i.pinimg.com/originals/65/20/a0/6520a0fdf108c7303e4bea4ea5966079.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://geniusvets.s3.amazonaws.com/gv-cat-breeds/American-Shorthair-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://cat-world.com/wp-content/uploads/2017/02/american-shorthair1.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #29 from http://3.bp.blogspot.com/_jZHHRfnq9F8/TVEM3kDKb0I/AAAAAAAAMPc/mznTJxZTCs4/s1600/American+Shorthair+Cat.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #30 from https://cdn.fotofits.com/petzlover/gallery/img/l/american-shorthair-856157.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from http://www.wotcat.com/image/cat/american-shorthair.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
# [%] Downloading Image #32 from http://farm8.staticflickr.com/7244/7195407636_0b5a6e2d77_z.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://fullofcats.com/wp-content/uploads/2020/03/american-shorthair8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from http://metaphoricalplatypus.com/wp-content/uploads/2012/12/american-shorthair-cat.jpg
# [Error]Invalid image, not saving http://metaphoricalplatypus.com/wp-content/uploads/2012/12/american-shorthair-cat.jpg
#
# [!] Issue getting: http://metaphoricalplatypus.com/wp-content/uploads/2012/12/american-shorthair-cat.jpg
# [!] Error:: Invalid image, not saving http://metaphoricalplatypus.com/wp-content/uploads/2012/12/american-shorthair-cat.jpg
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #34 from http://3.bp.blogspot.com/-XNSSjjHmYm0/UTe4zV8lV7I/AAAAAAAAAd4/riPtwg0wUfE/s1600/black-american-shorthair-cat-8.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
# [%] Downloading Image #35 from https://dnl7t01l0fo05.cloudfront.net/fr/wp-content/uploads/sites/2/2018/01/9_american_shorthair.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
# [%] Downloading Image #36 from https://www.breedlist.com/Images_Content/Site1/Images/Pages/American-Shorthair2.jpg
# [Error]Invalid image, not saving https://www.breedlist.com/Images_Content/Site1/Images/Pages/American-Shorthair2.jpg
#
# [!] Issue getting: https://www.breedlist.com/Images_Content/Site1/Images/Pages/American-Shorthair2.jpg
# [!] Error:: Invalid image, not saving https://www.breedlist.com/Images_Content/Site1/Images/Pages/American-Shorthair2.jpg
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
# [%] Downloading Image #36 from https://2.bp.blogspot.com/-Z3ReuGEyK1s/UJ3B0ipWGhI/AAAAAAAABA8/N7gX4G0fmGg/s1600/American-Shorthair-Picture.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://s-media-cache-ak0.pinimg.com/736x/0f/e5/25/0fe525681e4a57052b20c3e6068ac569.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #38 from https://4.bp.blogspot.com/-NklUYzdbJK8/UWmE_QGRTtI/AAAAAAAAASM/0PKH5ZnUPXk/s1600/American_Shorthair2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://live.staticflickr.com/7233/7395148504_f06b330521_z.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 12
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 39 images.
# [%] Downloading Images to /content/data/Siamese Cat
#
#
# [!!]Indexing page: 1
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 0 images.

# %%
# Clean data
import os
import cv2
from PIL import Image
import numpy as np
import random

folders = common_cat_breeds

for folder in folders:
    print('Cleaning folder: ', folder)
    for i in os.listdir(f"data/{folder}"):
        img = cv2.imread(f"data/{folder}/{i}")
        if img is None or (not i.endswith('.jpg') and not i.endswith('.jpeg') and not i.endswith('.png')):
            print('img is none: ', i)
            os.system(f"rm 'data/{folder}/{i}'")

    for i in os.listdir(f"data/{folder}"):
        img = np.array(Image.open(f"data/{folder}/{i}").convert('RGB'))
        cv2.imwrite(f"data/{folder}/{i}", img)
# Out:
# Cleaning folder:  Maine Coon
# img is none:  Image_9.JPG
# Cleaning folder:  Persian Cat
# Cleaning folder:  American Shorthair
# Cleaning folder:  Siamese Cat

# %%
# Split data into train-val and test
import random

random.seed(42)
os.mkdir('data/train')
os.mkdir('data/test')

for folder in folders:
	files = os.listdir(f'data/{folder}')
	random.shuffle(files)
	t = int(0.8 * len(files))
	os.system(f"mv 'data/{folder}' data/train/")
	os.system(f"mkdir 'data/test/{folder}'")
	for f in files[t:]:
		os.system(f"mv 'data/train/{folder}/{f}' 'data/test/{folder}/'")

# %% [markdown]
# # Training the Model

# %%
## Importing the libraries
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_hub as hub
import sklearn.metrics as metrics
import seaborn as sns

# %%
## Hyperparams ##

LEARNING_RATE = 0.0001 # learning rate to be used by the model
BATCH_SIZE = 4
EPOCHS = 5
CLASSES = ['Maine Coon', 'Persian Cat', 'American Shorthair', 'Siamese Cat'] #
NUM_CLASSES = len(CLASSES)
IMG_SIZE = (224, 224) #

# %%
"""
Function: build_model
Description: Builds the model by using the pretrained model and adding the dropout layer and the dense layer
"""
def build_model(NUM_CLASSES, LEARNING_RATE):

    ## Input Layer ##

    input_layer = keras.layers.Input(shape=(224, 224, 3))

    ## EfficientNet B0 pretrain
    model = hub.KerasLayer('https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1', trainable=False)

    ## Dropout layer
    dropout = keras.layers.Dropout(rate=0.2)

    ## Dense layer
    dense = keras.layers.Dense(NUM_CLASSES, activation='softmax')

    ## Build model by adding the pretrained model and the new layers
    model = keras.Sequential([
        input_layer,
        model,
        dropout,
        dense
    ])

    ## Compile model
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
model = build_model(NUM_CLASSES, LEARNING_RATE)

# %%
"""
Function : load_images
Description: Loads the images from the directory

"""
def load_dataset(directory, batch_size, image_size):

    ## ImageDataGenerator is used to perform data augmentation
    ## We use the following augmentation techniques to increase dataset size:
    ## - Horizontal flip: Flip the image horizontally, ie left to right
    ## - Rotate: Rotate the image by a random angle between -20 and 20 degrees
    ## - Zoom: Zoom in or out by a random factor between 0.8 and 1.2 times
    ## - Shift: Shift the image by a random horizontal and vertical offset of 20% of the image width or height
    train_data_gen = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2,
        horizontal_flip=True,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        zoom_range=0.2,
        fill_mode='nearest'
    )

    train_dataset = train_data_gen.flow_from_directory(
        directory,
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical',
        subset='training'
    )

    validation_dataset = train_data_gen.flow_from_directory(
        directory,
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical',
        subset='validation'
    )

    return train_dataset, validation_dataset

# %%
## Load the dataset
train_dataset, validation_dataset = load_dataset('data/train', BATCH_SIZE, IMG_SIZE)
# Out:
# Found 68 images belonging to 4 classes.
# Found 16 images belonging to 4 classes.

# %%
"""
Function: train
Description: Trains the model, saves the model and plots the training and validation loss and accuracy

"""

def train(model, train_dataset, validation_dataset, callbacks, epochs):

    history = model.fit_generator(
        train_dataset,
        epochs=epochs,
        validation_data=validation_dataset,
        verbose=1,
        callbacks=callbacks
    )

    return history

# %%
### Callbacks that will be called while training the model
## - ModelCheckpoint: Saves the model after every epoch
## - TensorBoard: Visualize the training and validation on browser

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath='models/model.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]

# %%
# Finally train the model, should see a progress bar while training
history = train(model, train_dataset, validation_dataset, callbacks=callbacks, epochs=EPOCHS)
# Out:
# <ipython-input-13-640e4bfc1ee9>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/5
# 17/17 [==============================] - ETA: 0s - loss: 1.4095 - accuracy: 0.2353
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 17/17 [==============================] - 22s 181ms/step - loss: 1.4095 - accuracy: 0.2353 - val_loss: 1.3192 - val_accuracy: 0.2500
# Epoch 2/5
# 17/17 [==============================] - 2s 124ms/step - loss: 1.2710 - accuracy: 0.3676 - val_loss: 1.0842 - val_accuracy: 0.5000
# Epoch 3/5
# 17/17 [==============================] - 2s 132ms/step - loss: 1.1369 - accuracy: 0.5147 - val_loss: 1.0802 - val_accuracy: 0.5625
# Epoch 4/5
# 17/17 [==============================] - 3s 192ms/step - loss: 1.0737 - accuracy: 0.5147 - val_loss: 1.0454 - val_accuracy: 0.5625
# Epoch 5/5
# 17/17 [==============================] - 2s 125ms/step - loss: 0.9842 - accuracy: 0.6324 - val_loss: 0.9317 - val_accuracy: 0.6875

# %%
## Plot the training and validation loss and accuracy
fig = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png')

fig = plt.figure(figsize=(10, 10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png')

# %% [markdown]
# # Testing the Model

# %%
# Getting the test dataset
test_data_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.0,
    fill_mode='nearest',
)

test_dataset = test_data_gen.flow_from_directory(
    'data/test',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# %%
## Do predictions on the test set
predictions = model.predict(test_dataset)

# %%
## Get the original labels
test_labels = test_dataset.labels

# %%
## Compute confusion matrix
confusion = metrics.confusion_matrix(test_labels, predictions.argmax(1)).astype('float32')
confusion = confusion.astype("float") / confusion.sum(axis=1)

# %%
## Get heatmap
fig = plt.figure(figsize=(10, 10))
ax = sns.heatmap(
    confusion, xticklabels=CLASSES, yticklabels=CLASSES,
    cmap='Blues')

ax.figure.subplots_adjust(left = 0.3, bottom=0.4)


plt.title("Confusion matrix")
plt.ylabel("True label")
plt.xlabel("Predicted label")

plt.savefig('test_confusion_matrix.png')
